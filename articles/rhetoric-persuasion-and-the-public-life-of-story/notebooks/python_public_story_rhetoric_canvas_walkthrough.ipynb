# %% [markdown]
# # Rhetoric, Persuasion, and the Public Life of Story\n\nNotebook placeholder for Python-based public story rhetoric Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
