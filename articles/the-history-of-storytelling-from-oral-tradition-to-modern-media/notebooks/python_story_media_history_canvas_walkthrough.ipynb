# %% [markdown]
# # The History of Storytelling from Oral Tradition to Modern Media\n\nNotebook placeholder for Python-based story media history Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
