# %% [markdown]
# # Reversal, Recognition, and Transformation\n\nNotebook placeholder for Python-based reversal recognition Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
