# %% [markdown]
# # Performance, Memory, and Variation in Oral Storytelling\n\nNotebook placeholder for Python-based oral storytelling variation Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
