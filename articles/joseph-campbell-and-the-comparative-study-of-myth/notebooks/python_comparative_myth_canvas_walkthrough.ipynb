# %% [markdown]
# # Joseph Campbell and the Comparative Study of Myth\n\nNotebook placeholder for Python-based comparative mythology Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
