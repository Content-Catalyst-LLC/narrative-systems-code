# %% [markdown]
# # The Monomyth: What Campbell Actually Argued\n\nNotebook placeholder for Python-based monomyth Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
