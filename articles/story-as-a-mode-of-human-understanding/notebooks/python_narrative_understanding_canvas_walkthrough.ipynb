# %% [markdown]
# # Story as a Mode of Human Understanding\n\nNotebook placeholder for Python-based narrative understanding Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
