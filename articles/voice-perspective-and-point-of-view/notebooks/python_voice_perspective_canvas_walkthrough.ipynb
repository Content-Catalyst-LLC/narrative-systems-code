# %% [markdown]
# # Voice, Perspective, and Point of View\n\nNotebook placeholder for Python-based voice perspective Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
