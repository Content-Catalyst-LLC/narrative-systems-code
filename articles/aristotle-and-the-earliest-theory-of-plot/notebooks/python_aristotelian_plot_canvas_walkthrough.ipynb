# %% [markdown]
# # Aristotle and the Earliest Theory of Plot\n\nNotebook placeholder for Python-based Aristotelian plot Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
