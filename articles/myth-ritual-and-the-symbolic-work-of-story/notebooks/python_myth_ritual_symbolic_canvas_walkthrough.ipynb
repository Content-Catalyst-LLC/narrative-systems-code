# %% [markdown]
# # Myth, Ritual, and the Symbolic Work of Story\n\nNotebook placeholder for Python-based myth and ritual symbolic Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
