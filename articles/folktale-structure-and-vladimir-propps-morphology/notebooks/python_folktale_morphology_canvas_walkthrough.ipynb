# %% [markdown]
# # Folktale Structure and Vladimir Propp’s Morphology\n\nNotebook placeholder for Python-based folktale morphology Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
