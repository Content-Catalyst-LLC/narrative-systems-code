# %% [markdown]
# # Oral Tradition, Performance, and Collective Memory\n\nNotebook placeholder for Python-based oral tradition Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
