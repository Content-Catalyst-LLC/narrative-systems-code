# %% [markdown]
# # Why Storytelling Matters in Human Culture\n\nNotebook placeholder for Python-based cultural storytelling Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
