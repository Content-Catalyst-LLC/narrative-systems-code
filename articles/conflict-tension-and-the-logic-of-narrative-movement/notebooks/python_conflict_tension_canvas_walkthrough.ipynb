# %% [markdown]
# # Conflict, Tension, and the Logic of Narrative Movement\n\nNotebook placeholder for Python-based conflict and tension Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
