# %% [markdown]
# # Proverb, Song, Chant, and Ritual Speech\n\nNotebook placeholder for Python-based compact oral forms Canvas analysis.\n\nUse the scripts in `../python/` as the reproducible source of truth.
